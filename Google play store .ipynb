# %%
import pandas as pd
import numpy as np

# Generating sample Google Play Store data
data = {
    'App': [f'App_{i}' for i in range(1, 31)],
    'Category': np.random.choice(['Game', 'Productivity', 'Health', 'Education'], 30),
    'Rating': np.random.uniform(1.0, 5.0, 30).round(1),
    'Reviews': np.random.randint(1, 10000, 30),
    'Size': np.random.choice(['Varies with device', '10M', '20M', '30M'], 30),
    'Installs': np.random.choice(['1,000+', '10,000+', '50,000+', '100,000+'], 30),
    'Type': np.random.choice(['Free', 'Paid'], 30),
    'Price': np.random.choice(['0', '0.99', '1.99', '2.99', '4.99', '5.99', '9.99'], 30),
    'Content Rating': np.random.choice(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], 30)
}

# %%
type(data)
# Out:
# dict

# %%
#data = { 'column1' :  }

# %% [markdown]
# diff lib offer diff function
# pandas -
# numpy -
# matplotlib

# %%
# Creating DataFrame
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#      App Category  Rating  Reviews                Size  Installs  Type Price  \
# 0  App_1   Health     4.9     7851  Varies with device    1,000+  Free  2.99
# 1  App_2     Game     2.3     5289                 20M  100,000+  Free  2.99
# 2  App_3     Game     2.4     1016                 30M   50,000+  Paid  2.99
# 3  App_4     Game     2.2     4931                 20M    1,000+  Paid  0.99
# 4  App_5     Game     3.4     7879  Varies with device   10,000+  Free     0
#
#   Content Rating
# 0     Mature 17+
# 1           Teen
# 2     Mature 17+
# 3     Mature 17+
# 4       Everyone

# %%
df.tail(2)
# Out:
#        App      Category  Rating  Reviews Size Installs  Type Price  \
# 28  App_29        Health     2.5     1698  30M  50,000+  Paid  4.99
# 29  App_30  Productivity     3.3     6269  30M  50,000+  Free  9.99
#
#    Content Rating
# 28   Everyone 10+
# 29           Teen

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             30 non-null     object
#  1   Category        30 non-null     object
#  2   Rating          30 non-null     float64
#  3   Reviews         30 non-null     int32
#  4   Size            30 non-null     object
#  5   Installs        30 non-null     object
#  6   Type            30 non-null     object
#  7   Price           30 non-null     object
#  8   Content Rating  30 non-null     object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 2.1+ KB

# %%
df['App']
# Out:
# 0      App_1
# 1      App_2
# 2      App_3
# 3      App_4
# 4      App_5
# 5      App_6
# 6      App_7
# 7      App_8
# 8      App_9
# 9     App_10
# 10    App_11
# 11    App_12
# 12    App_13
# 13    App_14
# 14    App_15
# 15    App_16
# 16    App_17
# 17    App_18
# 18    App_19
# 19    App_20
# 20    App_21
# 21    App_22
# 22    App_23
# 23    App_24
# 24    App_25
# 25    App_26
# 26    App_27
# 27    App_28
# 28    App_29
# 29    App_30
# Name: App, dtype: object

# %%
df['App'].replace('App_1', 'Facebook')
# Out:
# 0     Facebook
# 1        App_2
# 2        App_3
# 3        App_4
# 4        App_5
# 5        App_6
# 6        App_7
# 7        App_8
# 8        App_9
# 9       App_10
# 10      App_11
# 11      App_12
# 12      App_13
# 13      App_14
# 14      App_15
# 15      App_16
# 16      App_17
# 17      App_18
# 18      App_19
# 19      App_20
# 20      App_21
# 21      App_22
# 22      App_23
# 23      App_24
# 24      App_25
# 25      App_26
# 26      App_27
# 27      App_28
# 28      App_29
# 29      App_30
# Name: App, dtype: object

# %%
apps = [
    "WhatsApp Messenger",
    "Facebook",
    "Instagram",
    "TikTok",
    "YouTube",
    "Google Maps",
    "Snapchat",
    "Spotify",
    "Netflix",
    "Twitter",
    "Amazon Shopping",
    "Gmail",
    "Uber",
    "Google Drive",
    "Pinterest",
    "Microsoft Outlook",
    "Telegram",
    "Zoom",
    "Google Photos",
    "LinkedIn",
    "Duolingo",
    "Reddit",
    "Disney+",
    "Venmo",
    "eBay",
    "Fitbit",
    "Adobe Acrobat Reader",
    "Google Calendar",
     "Slack",
   
    "Strava"
]

# %%
#dataframe_name["column_name"] = list_name 
df['App']

# %%
df['App'] = apps

# %%
df['App'] = apps
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df['App'] = apps
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
#    4145     if (
#    4146         key in self.columns
#    4147         and value.ndim == 1
#    4148         and not is_extension_array_dtype(value)
#    4149     ):
#    4150         # broadcast across multiple columns if necessary
#    4151         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4870, in DataFrame._sanitize_column(self, value)
#    4867     return _reindex_for_setitem(Series(value), self.index)
#    4869 if is_list_like(value):
# -> 4870     com.require_length_match(value, self.index)
#    4871 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:576, in require_length_match(data, index)
#     572 """
#     573 Check the length of data matches the length of the index.
#     574 """
#     575 if len(data) != len(index):
# --> 576     raise ValueError(
#     577         "Length of values "
#     578         f"({len(data)}) "
#     579         "does not match length of index "
#     580         f"({len(index)})"
#     581     )
#
# ValueError: Length of values (29) does not match length of index (30)

# %%
df['App']
# Out:
# 0       WhatsApp Messenger
# 1                 Facebook
# 2                Instagram
# 3                   TikTok
# 4                  YouTube
# 5              Google Maps
# 6                 Snapchat
# 7                  Spotify
# 8                  Netflix
# 9                  Twitter
# 10         Amazon Shopping
# 11                   Gmail
# 12                    Uber
# 13            Google Drive
# 14               Pinterest
# 15       Microsoft Outlook
# 16                Telegram
# 17                    Zoom
# 18           Google Photos
# 19                LinkedIn
# 20                Duolingo
# 21                  Reddit
# 22                 Disney+
# 23                   Venmo
# 24                    eBay
# 25                  Fitbit
# 26    Adobe Acrobat Reader
# 27         Google Calendar
# 28                   Slack
# 29                  Strava
# Name: App, dtype: object

# %%
df
# Out:
#                      App      Category  Rating  Reviews                Size  \
# 0     WhatsApp Messenger        Health     4.9     7851  Varies with device
# 1               Facebook          Game     2.3     5289                 20M
# 2              Instagram          Game     2.4     1016                 30M
# 3                 TikTok          Game     2.2     4931                 20M
# 4                YouTube          Game     3.4     7879  Varies with device
# 5            Google Maps          Game     4.2     8206                 30M
# 6               Snapchat  Productivity     1.8      835                 20M
# 7                Spotify          Game     4.9     7935                 30M
# 8                Netflix        Health     3.8     5815                 10M
# 9                Twitter     Education     2.7     3513                 10M
# 10       Amazon Shopping          Game     1.6     5483  Varies with device
# 11                 Gmail        Health     2.6     8493  Varies with device
# 12                  Uber  Productivity     4.5     7443  Varies with device
# 13          Google Drive  Productivity     2.2     1077                 30M
# 14             Pinterest     Education     4.5     5614                 20M
# 15     Microsoft Outlook        Health     2.2     3789  Varies with device
# 16              Telegram          Game     4.8     2184                 20M
# 17                  Zoom     Education     4.4     9719  Varies with device
# 18         Google Photos  Productivity     2.8     1666                 30M
# 19              LinkedIn  Productivity     4.4     2669                 10M
# 20              Duolingo        Health     4.6     6345                 10M
# 21                Reddit     Education     3.7      596                 20M
# 22               Disney+        Health     1.5     8233                 10M
# 23                 Venmo          Game     3.8     2776                 10M
# 24                  eBay        Health     4.6     2855                 30M
# 25                Fitbit     Education     3.9      682                 20M
# 26  Adobe Acrobat Reader  Productivity     4.0     9944                 10M
# 27       Google Calendar          Game     1.9     1613                 20M
# 28                 Slack        Health     2.5     1698                 30M
# 29                Strava  Productivity     3.3     6269                 30M
#
#     Installs  Type Price Content Rating
# 0     1,000+  Free  2.99     Mature 17+
# 1   100,000+  Free  2.99           Teen
# 2    50,000+  Paid  2.99     Mature 17+
# 3     1,000+  Paid  0.99     Mature 17+
# 4    10,000+  Free     0       Everyone
# 5    10,000+  Free     0           Teen
# 6    10,000+  Paid  9.99   Everyone 10+
# 7    10,000+  Free     0   Everyone 10+
# 8     1,000+  Free  0.99     Mature 17+
# 9     1,000+  Free  1.99       Everyone
# 10   10,000+  Free  4.99       Everyone
# 11   50,000+  Free  2.99     Mature 17+
# 12    1,000+  Paid  4.99           Teen
# 13    1,000+  Paid  5.99       Everyone
# 14  100,000+  Free  4.99           Teen
# 15    1,000+  Free  2.99   Everyone 10+
# 16    1,000+  Paid     0           Teen
# 17    1,000+  Paid  9.99     Mature 17+
# 18    1,000+  Free  0.99     Mature 17+
# 19    1,000+  Paid     0           Teen
# 20  100,000+  Paid  2.99     Mature 17+
# 21   10,000+  Paid  4.99   Everyone 10+
# 22    1,000+  Paid     0   Everyone 10+
# 23   10,000+  Paid  0.99     Mature 17+
# 24   50,000+  Paid  1.99   Everyone 10+
# 25   50,000+  Free  1.99   Everyone 10+
# 26    1,000+  Free  9.99     Mature 17+
# 27   50,000+  Paid  9.99   Everyone 10+
# 28   50,000+  Paid  4.99   Everyone 10+
# 29   50,000+  Free  9.99           Teen

# %%
for i in df["Content Rating"]:
    print(i)
# Out:
# Mature 17+
# Teen
# Mature 17+
# Mature 17+
# Everyone
# Teen
# Everyone 10+
# Everyone 10+
# Mature 17+
# Everyone
# Everyone
# Mature 17+
# Teen
# Everyone
# Teen
# Everyone 10+
# Teen
# Mature 17+
# Mature 17+
# Teen
# Mature 17+
# Everyone 10+
# Everyone 10+
# Mature 17+
# Everyone 10+
# Everyone 10+
# Mature 17+
# Everyone 10+
# Everyone 10+
# Teen

# %%
df['Content Rating']=df["Content Rating"].replace("Mature 17+","Mature18+")

# %%
df["Rating"].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: Rating, dtype: bool

# %%
df["Rating"]
# Out:
# 0     4.9
# 1     2.3
# 2     2.4
# 3     2.2
# 4     3.4
# 5     4.2
# 6     1.8
# 7     4.9
# 8     3.8
# 9     2.7
# 10    1.6
# 11    2.6
# 12    4.5
# 13    2.2
# 14    4.5
# 15    2.2
# 16    4.8
# 17    4.4
# 18    2.8
# 19    4.4
# 20    4.6
# 21    3.7
# 22    1.5
# 23    3.8
# 24    4.6
# 25    3.9
# 26    4.0
# 27    1.9
# 28    2.5
# 29    3.3
# Name: Rating, dtype: float64

# %%
df.drop_duplicates(subset=['Rating'])
# Out:
#                      App      Category  Rating  Reviews                Size  \
# 0     WhatsApp Messenger        Health     4.9     7851  Varies with device
# 1               Facebook          Game     2.3     5289                 20M
# 2              Instagram          Game     2.4     1016                 30M
# 3                 TikTok          Game     2.2     4931                 20M
# 4                YouTube          Game     3.4     7879  Varies with device
# 5            Google Maps          Game     4.2     8206                 30M
# 6               Snapchat  Productivity     1.8      835                 20M
# 8                Netflix        Health     3.8     5815                 10M
# 9                Twitter     Education     2.7     3513                 10M
# 10       Amazon Shopping          Game     1.6     5483  Varies with device
# 11                 Gmail        Health     2.6     8493  Varies with device
# 12                  Uber  Productivity     4.5     7443  Varies with device
# 16              Telegram          Game     4.8     2184                 20M
# 17                  Zoom     Education     4.4     9719  Varies with device
# 18         Google Photos  Productivity     2.8     1666                 30M
# 20              Duolingo        Health     4.6     6345                 10M
# 21                Reddit     Education     3.7      596                 20M
# 22               Disney+        Health     1.5     8233                 10M
# 25                Fitbit     Education     3.9      682                 20M
# 26  Adobe Acrobat Reader  Productivity     4.0     9944                 10M
# 27       Google Calendar          Game     1.9     1613                 20M
# 28                 Slack        Health     2.5     1698                 30M
# 29                Strava  Productivity     3.3     6269                 30M
#
#     Installs  Type Price Content Rating
# 0     1,000+  Free  2.99      Mature18+
# 1   100,000+  Free  2.99           Teen
# 2    50,000+  Paid  2.99      Mature18+
# 3     1,000+  Paid  0.99      Mature18+
# 4    10,000+  Free     0       Everyone
# 5    10,000+  Free     0           Teen
# 6    10,000+  Paid  9.99   Everyone 10+
# 8     1,000+  Free  0.99      Mature18+
# 9     1,000+  Free  1.99       Everyone
# 10   10,000+  Free  4.99       Everyone
# 11   50,000+  Free  2.99      Mature18+
# 12    1,000+  Paid  4.99           Teen
# 16    1,000+  Paid     0           Teen
# 17    1,000+  Paid  9.99      Mature18+
# 18    1,000+  Free  0.99      Mature18+
# 20  100,000+  Paid  2.99      Mature18+
# 21   10,000+  Paid  4.99   Everyone 10+
# 22    1,000+  Paid     0   Everyone 10+
# 25   50,000+  Free  1.99   Everyone 10+
# 26    1,000+  Free  9.99      Mature18+
# 27   50,000+  Paid  9.99   Everyone 10+
# 28   50,000+  Paid  4.99   Everyone 10+
# 29   50,000+  Free  9.99           Teen

# %%
# Additional Steps
# Step 2: Remove duplicates based on the 'App' column
#df = df.drop_duplicates(subset=['Rating'])

# %%
df
# Out:
#                      App      Category  Rating  Reviews                Size  \
# 0     WhatsApp Messenger        Health     4.9     7851  Varies with device
# 1               Facebook          Game     2.3     5289                 20M
# 2              Instagram          Game     2.4     1016                 30M
# 3                 TikTok          Game     2.2     4931                 20M
# 4                YouTube          Game     3.4     7879  Varies with device
# 5            Google Maps          Game     4.2     8206                 30M
# 6               Snapchat  Productivity     1.8      835                 20M
# 7                Spotify          Game     4.9     7935                 30M
# 8                Netflix        Health     3.8     5815                 10M
# 9                Twitter     Education     2.7     3513                 10M
# 10       Amazon Shopping          Game     1.6     5483  Varies with device
# 11                 Gmail        Health     2.6     8493  Varies with device
# 12                  Uber  Productivity     4.5     7443  Varies with device
# 13          Google Drive  Productivity     2.2     1077                 30M
# 14             Pinterest     Education     4.5     5614                 20M
# 15     Microsoft Outlook        Health     2.2     3789  Varies with device
# 16              Telegram          Game     4.8     2184                 20M
# 17                  Zoom     Education     4.4     9719  Varies with device
# 18         Google Photos  Productivity     2.8     1666                 30M
# 19              LinkedIn  Productivity     4.4     2669                 10M
# 20              Duolingo        Health     4.6     6345                 10M
# 21                Reddit     Education     3.7      596                 20M
# 22               Disney+        Health     1.5     8233                 10M
# 23                 Venmo          Game     3.8     2776                 10M
# 24                  eBay        Health     4.6     2855                 30M
# 25                Fitbit     Education     3.9      682                 20M
# 26  Adobe Acrobat Reader  Productivity     4.0     9944                 10M
# 27       Google Calendar          Game     1.9     1613                 20M
# 28                 Slack        Health     2.5     1698                 30M
# 29                Strava  Productivity     3.3     6269                 30M
#
#     Installs  Type Price Content Rating
# 0     1,000+  Free  2.99      Mature18+
# 1   100,000+  Free  2.99           Teen
# 2    50,000+  Paid  2.99      Mature18+
# 3     1,000+  Paid  0.99      Mature18+
# 4    10,000+  Free     0       Everyone
# 5    10,000+  Free     0           Teen
# 6    10,000+  Paid  9.99   Everyone 10+
# 7    10,000+  Free     0   Everyone 10+
# 8     1,000+  Free  0.99      Mature18+
# 9     1,000+  Free  1.99       Everyone
# 10   10,000+  Free  4.99       Everyone
# 11   50,000+  Free  2.99      Mature18+
# 12    1,000+  Paid  4.99           Teen
# 13    1,000+  Paid  5.99       Everyone
# 14  100,000+  Free  4.99           Teen
# 15    1,000+  Free  2.99   Everyone 10+
# 16    1,000+  Paid     0           Teen
# 17    1,000+  Paid  9.99      Mature18+
# 18    1,000+  Free  0.99      Mature18+
# 19    1,000+  Paid     0           Teen
# 20  100,000+  Paid  2.99      Mature18+
# 21   10,000+  Paid  4.99   Everyone 10+
# 22    1,000+  Paid     0   Everyone 10+
# 23   10,000+  Paid  0.99      Mature18+
# 24   50,000+  Paid  1.99   Everyone 10+
# 25   50,000+  Free  1.99   Everyone 10+
# 26    1,000+  Free  9.99      Mature18+
# 27   50,000+  Paid  9.99   Everyone 10+
# 28   50,000+  Paid  4.99   Everyone 10+
# 29   50,000+  Free  9.99           Teen

# %%
apps[0] = "0"

# %%
apps
# Out:
# ['0',
#  'Facebook',
#  'Instagram',
#  'TikTok',
#  'YouTube',
#  'Google Maps',
#  'Snapchat',
#  'Spotify',
#  'Netflix',
#  'Twitter',
#  'Amazon Shopping',
#  'Gmail',
#  'Uber',
#  'Google Drive',
#  'Pinterest',
#  'Microsoft Outlook',
#  'Telegram',
#  'Zoom',
#  'Google Photos',
#  'LinkedIn',
#  'Duolingo',
#  'Reddit',
#  'Disney+',
#  'Venmo',
#  'eBay',
#  'Fitbit',
#  'Adobe Acrobat Reader',
#  'Google Calendar',
#  'Slack',
#  'Strava']

# %%
# Step 3: Fill missing values in 'Rating' with the mean rating
df['Rating'] = df['Rating'].fillna(df['Rating'].mean())

# %%
# Step 4: Normalize the 'Reviews' column (scaling between 0 and 1)
df['Reviews'] = (df['Reviews'] - df['Reviews'].min()) / (df['Reviews'].max() - df['Reviews'].min())

# %%
# Step 5: Simplify 'Size' column (replace 'Varies with device' with NaN)
df['Size'] = df['Size'].replace('Varies with device', np.nan)

# %%
# Step 6: Convert 'Size' from string to numeric (assume 'M' means MB)
df['Size'] = df['Size'].str.replace('M', '').astype(float)

# %%
# Step 7: Fill missing values in 'Size' with the median size
df['Size'] = df['Size'].fillna(df['Size'].median())

# %%
# Step 8: Clean 'Installs' column (remove '+' and ',')
df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '').astype(int)

# %%
# Step 9: Create a new column 'Log_Installs' (log transformation of 'Installs')
df['Log_Installs'] = np.log1p(df['Installs'])

# %%
# Step 10: Normalize 'Log_Installs' column
df['Log_Installs'] = (df['Log_Installs'] - df['Log_Installs'].min()) / (df['Log_Installs'].max() - df['Log_Installs'].min())

# %%
# Step 11: Create a new column 'Popularity' based on 'Rating' and 'Reviews'
df['Popularity'] = df['Rating'] * df['Reviews']

# %%
# Check and categorize paid apps
df['Affordable'] = np.where(df['Type'] == 'Paid', np.where(df['Price'] < 5.00, 'Yes', 'No'), 'N/A')

# %%
# Display the DataFrame
print(df)
